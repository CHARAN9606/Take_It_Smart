# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Charan\Desktop\JavaScript\Internship\TAKEITSMART\telecomedata.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# data.loc[:,'gender'].dtype
data.loc[:,'gender'].isnull().sum()
# Out:
# 0

# %%
data.loc[:,'gender'].mode()[0]
# Out:
# 'Male'

# %%
data.loc[:,'gender'] = data.loc[:,'gender'].fillna(data.loc[:,'gender'].mode()[0])

# %%
data.loc[:,'gender'].isnull().sum()
# Out:
# 0

# %%
data.loc[:,'tenure'].mode()[0]
# Out:
# 1

# %%
data.loc[:,'tenure'] = data.loc[:,'tenure'].fillna(data.loc[:,'tenure'].mode()[0])

# %%
data.loc[:,'tenure'].isnull().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,3))
sns.histplot(data,x='MonthlyCharges',kde=True)
plt.show()

# %%
# normal [-0.5 , 0.5]
# left skew[<-0.5]
# right skew[>0.5]

data.loc[:,'MonthlyCharges'].skew()
# Out:
# -0.22052443394398033

# %%
data.loc[:,'MonthlyCharges'].mean()
# Out:
# 64.76169246059922

# %%
data.loc[:,'MonthlyCharges']=data.loc[:,'MonthlyCharges'].fillna(data.loc[:,'MonthlyCharges'].mean())

# %%
data.loc[:,'MonthlyCharges'].isnull().sum()
# Out:
# 0

# %%
data.loc[:,'TotalCharges'].dtype
# Out:
# dtype('O')

# %%
data.loc[:,'Total_charges'] = pd.to_numeric(data.loc[:,'TotalCharges'],errors='coerce')

# %%
data.loc[:,'Total_charges'].dtype
# Out:
# dtype('float64')

# %%
data.drop(columns='TotalCharges',inplace=True)

# %%
plt.figure(figsize=(5,3))
sns.histplot(data,x='Total_charges',kde=True)
plt.show()

# %%
data.loc[:,'Total_charges'].median()
# Out:
# 1397.475

# %%
data.loc[:,'Total_Charges'] = data.loc[:,'Total_charges'].fillna(data.loc[:,'Total_charges'].median())

# %%
data.loc[:,'Total_charges'].skew()
# Out:
# 0.9637890936414893

# %%
plt.figure(figsize=(5,3))
sns.histplot(data,x='Total_Charges',kde=True)
plt.show()
